# %%
using DataTables
using Plots
using StatsBase
using Distributions
using StatsFuns
using KernelDensity
using Statistics
using StatsPlots
using CSV
using DataFrames
using LaTeXStrings
using LsqFit
using DelimitedFiles

# %%
cars = [126, 134, 156, 124, 161, 129, 154, 150, 151, 153, 123, 125, 116, 115, 139, 106, 98, 107, 108, 114, 104, 93, 119, 82]
# Out:
# 24-element Vector{Int64}:
#  126
#  134
#  156
#  124
#  161
#  129
#  154
#  150
#  151
#  153
#    ⋮
#  106
#   98
#  107
#  108
#  114
#  104
#   93
#  119
#   82

# %%
scatter(cars)

# %%
cars2 = cars[1:2:23] .+ cars[2:2:24]
scatter(cars2)

# %%
cars2 = cars[1:3:22] .+ cars[2:3:23] .+ cars[3:3:24]
scatter(cars2)

# %%
function MA(X, n)
    S = Float64[]
    for i in 1 : length(X) - n + 1
        s = mean(X[i : i + n - 1])
        append!(S, s)
    end
    return S
end
# Out:
# MA (generic function with 1 method)

# %%
scatter(MA(cars, 2))

# %%
scatter(MA(cars, 3))

# %%
scatter(MA(cars, 4))

# %%
scatter(MA(cars, 5))
